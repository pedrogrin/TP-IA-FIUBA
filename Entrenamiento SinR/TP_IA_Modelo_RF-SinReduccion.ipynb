# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
#Configuración de parametros de Pandas para mejor visualización
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 3)
pd.set_option('plotting.backend', 'matplotlib') 
pd.options.mode.chained_assignment = None

# En produccion eliminar, se incluye por informacion
print(f'Pandas Version: {pd.__version__}')
# Out:
# Pandas Version: 1.5.3

# %%
X_train = pd.read_csv('/home/pedro/TpIAFiuba/Datos/X_train_con_escalado.csv', encoding = 'unicode_escape')
X_test = pd.read_csv('/home/pedro/TpIAFiuba/Datos/X_test_con_escalado.csv', encoding = 'unicode_escape')

y_train = pd.read_csv('/home/pedro/TpIAFiuba/Datos/y_train.csv', encoding = 'unicode_escape').to_numpy().reshape(-1)
y_test = pd.read_csv('/home/pedro/TpIAFiuba/Datos/y_test.csv', encoding = 'unicode_escape').to_numpy().reshape(-1)

# %%
len(X_train), len(X_test)
# Out:
# (38312, 16422)

# %%
rf = RandomForestClassifier(random_state=10)

# %%
params = [
    {'n_estimators': [80, 100, 120]},
    {'max_depth': [5, 10, 15]},
    {"min_samples_split": [2, 5]},
    {"min_samples_leaf": [1, 2]},
    {"random_state":[10]}
]

# %%
gs = GridSearchCV(rf, param_grid = params, cv=5, scoring='recall')

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=10),
#              param_grid=[{'n_estimators': [80, 100, 120]},
#                          {'max_depth': [5, 10, 15]},
#                          {'min_samples_split': [2, 5]},
#                          {'min_samples_leaf': [1, 2]}, {'random_state': [10]}],
#              scoring='recall')

# %%
gs.best_params_
# Out:
# {'min_samples_leaf': 2}

# %%
gs.best_score_
# Out:
# 0.7810081501910849

# %%
rf_clf = gs.best_estimator_

# %%
rf_clf
# Out:
# RandomForestClassifier(min_samples_leaf=2, random_state=10)

# %%
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=2, random_state=10)

# %%
from sklearn.metrics import recall_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
preds = rf_clf.predict(X_test)

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.74      8211
#            1       0.74      0.78      0.76      8211
#
#     accuracy                           0.75     16422
#    macro avg       0.75      0.75      0.75     16422
# weighted avg       0.75      0.75      0.75     16422

# %%
recall_score(y_test, preds)
# Out:
# 0.7782243332115455

# %%
accuracy_score(y_test, preds)
# Out:
# 0.7516745828766289

# %%
cm = confusion_matrix(y_test, preds)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf_clf.classes_)
disp.plot()

# %%
plt.bar(X_train.columns, rf_clf.feature_importances_)
plt.xlabel('Features')
plt.ylabel('Importancia')
plt.title('Importancia Features con RF')
plt.xticks(rotation=90)
plt.show()

# %%
import eli5 as eli
# Out:
# 2023-07-08 13:31:53.254927: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-08 13:31:53.562525: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-08 13:31:53.566899: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-08 13:31:55.455914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
eli.explain_weights(rf_clf)
# Out:
# Explanation(estimator='RandomForestClassifier(min_samples_leaf=2, random_state=10)', description='\nRandom forest feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='x0', weight=0.17310854085014968, std=0.006954486765806686, value=None), FeatureWeight(feature='x4', weight=0.07765621975885886, std=0.021608931666041064, value=None), FeatureWeight(feature='x6', weight=0.07564655548186647, std=0.036441423691659515, value=None), FeatureWeight(feature='x21', weight=0.0697062333687308, std=0.0036246807318617074, value=None), FeatureWeight(feature='x16', weight=0.06426860311790195, std=0.025992092696845492, value=None), FeatureWeight(feature='x19', weight=0.056831613022294246, std=0.016752703294146833, value=None), FeatureWeight(feature='x5', weight=0.05427914469743292, std=0.0038284764876095542, value=None), FeatureWeight(feature='x12', weight=0.04643181312553332, std=0.008471246045410998, value=None), FeatureWeight(feature='x3', weight=0.04304058830028813, std=0.014729487288419564, value=None), FeatureWeight(feature='x11', weight=0.03763263780689715, std=0.006959278293203807, value=None), FeatureWeight(feature='x1', weight=0.033409012542449566, std=0.009803154632638323, value=None), FeatureWeight(feature='x9', weight=0.031008328211627932, std=0.0064799931546648615, value=None), FeatureWeight(feature='x10', weight=0.02944250917269149, std=0.0030889506652445734, value=None), FeatureWeight(feature='x20', weight=0.02762478265138851, std=0.007142625210896447, value=None), FeatureWeight(feature='x14', weight=0.025079201973109422, std=0.0035148438288529972, value=None), FeatureWeight(feature='x17', weight=0.021489350937896792, std=0.0049290734699014, value=None), FeatureWeight(feature='x18', weight=0.018291444092847414, std=0.011258535009364292, value=None), FeatureWeight(feature='x23', weight=0.017923715589831024, std=0.009131084046119481, value=None), FeatureWeight(feature='x7', weight=0.017750240459673033, std=0.008522284695017028, value=None), FeatureWeight(feature='x24', weight=0.017476233440295842, std=0.0026935961432387944, value=None)], remaining=5), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# Un ejemplo para una prediccion con resultado 0 y otra con resultado 1

# %%
eli.explain_prediction(rf_clf, np.array(X_test)[1])
# Out:
# /home/pedro/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Explanation(estimator='RandomForestClassifier(min_samples_leaf=2, random_state=10)', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble (or a single tree for DecisionTreeClassifier).\nEach node of the tree has an output score, and contribution of a feature\non the decision path is how much the score changes from parent to child.\nWeights of all features sum to the output score or proba of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision path', is_regression=False, targets=[TargetExplanation(target=0, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=0.5002226456462726, std=None, value=1.0), FeatureWeight(feature='x19', weight=0.1012236333323706, std=None, value=0.0), FeatureWeight(feature='x14', weight=0.07642993787006969, std=None, value=1.0), FeatureWeight(feature='x7', weight=0.06873747284040523, std=None, value=0.0), FeatureWeight(feature='x6', weight=0.06774563671513815, std=None, value=0.0), FeatureWeight(feature='x4', weight=0.05646258482008862, std=None, value=-0.5496623123140226), FeatureWeight(feature='x8', weight=0.039567082699687485, std=None, value=1.0), FeatureWeight(feature='x3', weight=0.02791692172796303, std=None, value=0.0), FeatureWeight(feature='x10', weight=0.02561468925195346, std=None, value=0.0), FeatureWeight(feature='x17', weight=0.0191065973658643, std=None, value=1.0), FeatureWeight(feature='x15', weight=0.018759203196814584, std=None, value=0.0), FeatureWeight(feature='x18', weight=0.017806516073704298, std=None, value=0.0), FeatureWeight(feature='x23', weight=0.011499850610538594, std=None, value=0.0), FeatureWeight(feature='x22', weight=0.009419179677767541, std=None, value=0.0), FeatureWeight(feature='x24', weight=0.008462596860901169, std=None, value=0.0), FeatureWeight(feature='x21', weight=0.0041455131132415715, std=None, value=0.5350756503276779), FeatureWeight(feature='x9', weight=0.0028099301793794635, std=None, value=1.0), FeatureWeight(feature='x13', weight=0.002176958792829007, std=None, value=0.0), FeatureWeight(feature='x20', weight=0.0015511709568036692, std=None, value=1.0), FeatureWeight(feature='x0', weight=0.001538471055638705, std=None, value=-0.2168371987675181)], neg=[FeatureWeight(feature='x16', weight=-0.22072188867127954, std=None, value=1.0), FeatureWeight(feature='x1', weight=-0.05888171670697221, std=None, value=1.0), FeatureWeight(feature='x12', weight=-0.021192823518569066, std=None, value=1.0), FeatureWeight(feature='x5', weight=-0.018376881204280823, std=None, value=-0.5018842880503341), FeatureWeight(feature='x11', weight=-0.0019471205290921135, std=None, value=0.0), FeatureWeight(feature='x2', weight=-0.0013230464505621393, std=None, value=0.0)], pos_remaining=0, neg_remaining=0), proba=0.7387531157066759, score=None, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
y_test[1]
# Out:
# 0

# %%
eli.explain_prediction(rf_clf, np.array(X_test)[10000])
# Out:
# /home/pedro/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Explanation(estimator='RandomForestClassifier(min_samples_leaf=2, random_state=10)', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble (or a single tree for DecisionTreeClassifier).\nEach node of the tree has an output score, and contribution of a feature\non the decision path is how much the score changes from parent to child.\nWeights of all features sum to the output score or proba of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision path', is_regression=False, targets=[TargetExplanation(target=1, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=0.4997773543537272, std=None, value=1.0), FeatureWeight(feature='x16', weight=0.13429844182172854, std=None, value=1.0), FeatureWeight(feature='x6', weight=0.12011038390429386, std=None, value=1.0), FeatureWeight(feature='x19', weight=0.03920957662064477, std=None, value=1.0), FeatureWeight(feature='x1', weight=0.031051522438736854, std=None, value=1.0), FeatureWeight(feature='x7', weight=0.030371987302523138, std=None, value=1.0), FeatureWeight(feature='x8', weight=0.02462411198121878, std=None, value=0.0), FeatureWeight(feature='x14', weight=0.021028401225108812, std=None, value=0.0), FeatureWeight(feature='x20', weight=0.017946261175944993, std=None, value=1.0), FeatureWeight(feature='x10', weight=0.011331472252906564, std=None, value=0.0), FeatureWeight(feature='x21', weight=0.01017596309028261, std=None, value=-0.7054579844895085), FeatureWeight(feature='x15', weight=0.004381653072659738, std=None, value=1.0), FeatureWeight(feature='x12', weight=0.0033379296257076184, std=None, value=1.0), FeatureWeight(feature='x13', weight=0.0017596140177458253, std=None, value=0.0)], neg=[FeatureWeight(feature='x4', weight=-0.031411959637137575, std=None, value=-0.5496623123140226), FeatureWeight(feature='x9', weight=-0.027528427289015132, std=None, value=1.0), FeatureWeight(feature='x3', weight=-0.02497460082211568, std=None, value=0.0), FeatureWeight(feature='x23', weight=-0.013090608309830984, std=None, value=0.0), FeatureWeight(feature='x0', weight=-0.01104105571885959, std=None, value=2.359879679357874), FeatureWeight(feature='x17', weight=-0.010821903025893103, std=None, value=1.0), FeatureWeight(feature='x5', weight=-0.0057929760694309185, std=None, value=0.0830961755905886), FeatureWeight(feature='x18', weight=-0.00528471576464252, std=None, value=0.0), FeatureWeight(feature='x22', weight=-0.004347845778431216, std=None, value=0.0), FeatureWeight(feature='x11', weight=-0.0031093129687343314, std=None, value=0.0), FeatureWeight(feature='x2', weight=-0.0008590900536808605, std=None, value=0.0), FeatureWeight(feature='x24', weight=-0.0003042653575453863, std=None, value=0.0)], pos_remaining=0, neg_remaining=0), proba=0.810837912087912, score=None, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
y_test[10000]
# Out:
# 1

# %%
from joblib import dump

# %%
dump(rf_clf, '/home/pedro/TpIAFiuba/Modelos/RF_Model_sinReduccion.joblib')
# Out:
# ['/home/pedro/TpIAFiuba/Modelos/RF_Model_sinReduccion.joblib']
